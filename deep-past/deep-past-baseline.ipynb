# %% [markdown]
# # Deep Past Challenge - Akkadian to English Translation Baseline
#
# TF-IDF nearest neighbor approach: find the most similar Akkadian text in training data and use its English translation.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA_DIR = Path('/kaggle/input/competitions/deep-past-initiative-machine-translation')

# Load data
train = pd.read_csv(DATA_DIR / 'train.csv')
test = pd.read_csv(DATA_DIR / 'test.csv')
sample_sub = pd.read_csv(DATA_DIR / 'sample_submission.csv')

# Print all column info for debugging
for name, df in [('train', train), ('test', test), ('sample_submission', sample_sub)]:
    print(f'=== {name} ({df.shape}) ===')
    print(f'Columns: {df.columns.tolist()}')
    print(df.head(3).to_string())
    print()
    for col in df.columns:
        print(f'  {col}: dtype={df[col].dtype}, sample={df[col].iloc[0]!r}')
    print()

# %%
# Placeholder - will be filled after confirming column names
pass

# %%
pass

# %%
pass

# %%
pass

# %%
# Create dummy submission for now
sample_sub.to_csv('/kaggle/working/submission.csv', index=False)
print('Dummy submission saved')
